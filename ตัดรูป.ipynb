# %% [markdown]
# <a href="https://colab.research.google.com/github/Athitiya00/efficientnet_keras_transfer_learning/blob/master/%E0%B8%95%E0%B8%B1%E0%B8%94%E0%B8%A3%E0%B8%B9%E0%B8%9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv (r'/content/drive/My Drive/cut_panoramic/All_Film7.csv')
df
# Out:
#       Fig_All  Fig_Gender  Age(year) Class  Filename  \
# 0           1           1          7   Y7F    V1.jpg
# 1           2           2          7   Y7F    V2.jpg
# 2           3           3          7   Y7F    V3.jpg
# 3           4           4          7   Y7F    V6.jpg
# 4           5           5          7   Y7F    V7.jpg
# ...       ...         ...        ...   ...       ...
# 2926      138          50         25  Y25M  J146.jpg
# 2927      139          51         25  Y25M  J166.jpg
# 2928      140          52         25  Y25M  J169.jpg
# 2929      141          53         25  Y25M  J183.jpg
# 2930      142          54         25  Y25M  J208.jpg
#
#                                           Path_filename      Sex Floder
# 0     /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# 1     /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# 2     /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# ...

# %%
Y7_1 = df[(df['Class'] == 'Y7F') & (df['Floder'] == 'Both')]
Y7_1
# Out:
#     Fig_All  Fig_Gender  Age(year) Class  Filename  \
# 0         1           1          7   Y7F    V1.jpg
# 1         2           2          7   Y7F    V2.jpg
# 2         3           3          7   Y7F    V3.jpg
# 3         4           4          7   Y7F    V6.jpg
# 4         5           5          7   Y7F    V7.jpg
# ..      ...         ...        ...   ...       ...
# 84       85          85          7   Y7F   V114jpg
# 85       86          86          7   Y7F  V115.jpg
# 86       87          87          7   Y7F  V116.jpg
# 87       88          88          7   Y7F  V118.jpg
# 88       89          89          7   Y7F  V119.jpg
#
#                                         Path_filename      Sex Floder
# 0   /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# 1   /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# 2   /content/drive/My Drive/Film pano/7 year/7Y-F/...  เพศหญิง   Both
# ...

# %%
/content/drive/MyDrive/cut_panoramic/7Y/7Y-F/Both

# %%
from PIL import Image
import matplotlib.pyplot as plt

path = Y7_1['Path_filename'].tolist()
frac = 0.60
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i)
    print(i)
    #left---------------------------------------------------
    left = 0
    upper = 0
    right = img.size[0]-((1-frac))*img.size[0]
    bottom = img.size[1]
    cropped_left = img.crop((left, upper, right, bottom))
    #save setting by youreself
    cropped_left.save('/content/drive/MyDrive/cut_panoramic/7Y/7Y-F/Both'+filename)
    
    # #right ---------------------------------------------------
    left = img.size[0]*((1-frac))
    upper = 0
    right = img.size[0]
    bottom = img.size[1]
    cropped_right= img.crop((left, upper, right, bottom))
    # #save setting by youreself
    cropped_left.save('/content/drive/MyDrive/cut_panoramic/7Y/7Y-F/Both'+filename)
    
    # #flip ---------------------------------------------------
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-f818ba553b75> in <module>
#       6 for i in path:
#       7     filename = i.split("/")[-1]
# ----> 8     img = Image.open(i)
#       9     print(i)
#      10     #left---------------------------------------------------
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Film pano/7 year/7Y-F/Both/V1.jpg'

# %%
/content/drive/MyDrive/Cut_Panoramic_Film/7 year/7Y-F/Both/left
